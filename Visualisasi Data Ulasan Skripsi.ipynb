# %%
import pandas as pd

data=pd.read_csv('DATA_SKRIPSI_STEMMING.csv', sep=';')
data.head()
# Out:
#             tanggal                                             ulasan  \
# 0  01/05/2023 22:08                ['suruh', 'tarik', 'dana', 'sulit']
# 1  01/05/2023 17:29  ['aplikasi', 'susah', 'tarik', 'uang', 'lain',...
# 2  01/05/2023 15:00          ['sesi', 'kadaluwarsa', 'akun', 'kecewa']
# 3  01/05/2023 05:31                                            ['oke']
# 4  01/05/2023 00:39  ['tarik', 'gagal', 'sulit', 'akun', 'tangguh',...
#
#      label
# 0  Negatif
# 1  Negatif
# 2  Negatif
# 3  Positif
# 4  Negatif

# %%
import ast

def join_text_list(texts):
    texts = ast.literal_eval(texts)
    return ' '.join([text for text in texts])
data["ulasan"] = data["ulasan"].apply(join_text_list)

data["ulasan"].head()
# Out:
# 0                               suruh tarik dana sulit
# 1    aplikasi susah tarik uang lain lain habis baru...
# 2                         sesi kadaluwarsa akun kecewa
# 3                                                  oke
# 4    tarik gagal sulit akun tangguh saldo juta hang...
# Name: ulasan, dtype: object

# %%
#MENYIMPAN FILE 

data.to_csv('DATA_SKRIPSI_VISUALISASI.csv')

# %%
#MEMBACA FILE YANG TADI DISIMPAN

df=pd.read_csv('DATA_SKRIPSI_VISUALISASI.csv', sep=';')
df.head()
# Out:
#    Unnamed: 0           tanggal  \
# 0           0  01/05/2023 22:08
# 1           1  01/05/2023 17:29
# 2           2  01/05/2023 15:00
# 3           3  01/05/2023 05:31
# 4           4  01/05/2023 00:39
#
#                                               ulasan    label
# 0                             suruh tarik dana sulit  Negatif
# 1  aplikasi susah tarik uang lain lain habis baru...  Negatif
# 2                       sesi kadaluwarsa akun kecewa  Negatif
# 3                                                oke  Positif
# 4  tarik gagal sulit akun tangguh saldo juta hang...  Negatif

# %%
positif = df.loc[df['label'] == "Positif"]
negatif = df.loc[df['label'] == "Negatif"]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 400, height = 400,
                     background_color = 'black',
                     min_font_size = 10).generate(' '.join(map(str, positif['ulasan'])))

plt.figure(figsize = (5,15), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
#plt.title('Positif', y=1, fontsize = 25)
plt.tight_layout(pad = 0)
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 400, height = 400,
                     background_color = 'black',
                     min_font_size = 10).generate(' '.join(map(str, negatif['ulasan'])))

plt.figure(figsize = (5,3), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
#plt.title('Negatif', fontsize = 20)
plt.tight_layout(pad = 0)
plt.show()
